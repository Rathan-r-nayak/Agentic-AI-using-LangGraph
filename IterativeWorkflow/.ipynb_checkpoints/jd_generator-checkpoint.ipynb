# %%
from langgraph.graph import StateGraph,START,END
from langchain_groq import ChatGroq
from langchain_ollama import ChatOllama
from typing import TypedDict,Literal,Annotated
from pydantic import BaseModel,Field
import operator
from langchain_core.messages import SystemMessage,HumanMessage
from IPython.display import Image

# %%
class JdState(TypedDict):
    requirment : str
    iteration : int
    max_iteration : int
    jd : str
    evaluation : Literal["accept", "reject"]
    feedback : str

    jd_history : Annotated[list[str], operator.add]
    feedback_history : Annotated[list[str], operator.add]

# %%
class EvaluationScehma(BaseModel):
    feedback : str = Field(description="feedback for later generation")
    evaluation : Literal["accept","reject"] = Field(description="evalutation result")

# %%
# generate the jd
generator_model = ChatGroq(model="llama-3.1-8b-instant")

# evaluate the jd
model = ChatOllama(model="llama3")
evaluator_structured_model = model.with_structured_output(EvaluationScehma)

# for regeneration
optimizer_model = ChatGroq(model="llama-3.1-8b-instant")

# %%
def generate_jd(state : JdState):
    messages = [
        SystemMessage(content="You are a professional job description generator."),
        HumanMessage(content=f"""
                \n\nGenerate the job description for the following requirments
                {state['requirment']}
                \n\nTLiteralhe JD should contain following things
                - Job Title
                - A highlight about key requirment of this job
                - Experience
                - About the Role
                - Key Responsibilities
                - Requirements
                - Location
                - Why Join Us?
                - Key Skills
                - About company
            """)
    ]
    output = generator_model.invoke(messages).content
    return {"jd" : output, "jd_history":[output], "iteration" : state['iteration'] + 1}

# %%
def evaluate_jd(state : JdState):
    message = [
        SystemMessage(content="You are a proffessional job description evaluator."),
        HumanMessage(content="""Evaluate the following jd based on the proffessionalism, quality of the jd and the format of the jd
    
        \n\n{state['jd']}""")
    ]

    output = evaluator_structured_model.invoke(message)
    return {"feedback" : output.feedback, "evaluation" : output.evaluation, "feedback_history" : [output.feedback]}

# %%
def route_control(state : JdState) -> Literal["accept","reject"]:
    if state['evaluation'] == "accept" and state['iteration'] >= state['max_iteration']:
        return "accept"
    else:
        return "reject"

# %%
def optimizer_jd(state : JdState):
    message = [
        SystemMessage(content="You are a professional job description optimizer. Optimize the JD based on the feedback"),
        HumanMessage(content=f"""Optimize the following job description
        \n\nrequirment : "{state['requirment']}"
        \n\nOriginal JD : "{state['jd']}"
        \n\nFeedback : "{state['feedback']}"
        \n\nThe JD should contain following things
                - Job Title
                - A highlight about key requirment of this job
                - Experience
                - About the Role
                - Key Responsibilities
                - Requirements
                - Location
                - Why Join Us?
                - Key Skills
                - About company
            """)
    ]
    output = optimizer_model.invoke(message).content
    return {"jd" : output, "jd_history":[output], "iteration" : state['iteration'] + 1}

# %%
graph = StateGraph(JdState)

graph.add_node("generate_jd",generate_jd)
graph.add_node("evaluate_jd",evaluate_jd)
graph.add_node("optimizer_jd",optimizer_jd)

graph.add_edge(START, "generate_jd")
graph.add_edge("generate_jd", "evaluate_jd")
graph.add_conditional_edges("evaluate_jd", route_control, {"accept" : END, "reject" : "optimizer_jd"})
graph.add_edge("optimizer_jd", "evaluate_jd")

workflow = graph.compile()

# %%
Image(workflow.get_graph().draw_mermaid_png())

# %%
requirment = """"We are looking for a highly skilled and motivated Data Scientist with strong expertise in Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI to join our growing team. This role requires hands-on experience in building intelligent systems, working with large-scale data, and developing production-ready AI solutions. The ideal candidate should have a strong foundation in data science concepts, modern AI frameworks, and real-world problem-solving abilities, along with the ability to collaborate effectively across teams.

The candidate is expected to have 3 to 6 years of experience in the Data Science and AI/ML domain, with practical exposure to building, training, and deploying machine learning and deep learning models. Experience in Generative AI, including large language models and multimodal systems, is highly preferred. The role involves working with cutting-edge technologies to design scalable and high-performance AI solutions that solve business problems across domains.

In this role, you will be responsible for designing, developing, and deploying machine learning and deep learning models for real-world applications. You will work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions. The role also involves developing Generative AI use cases, working with large language models, optimizing models for performance and scalability, and ensuring seamless integration with production systems. You will also contribute to experimentation, model evaluation, and continuous improvement of AI pipelines.

The ideal candidate should have strong programming skills in Python and be comfortable working in Linux and Windows environments. A solid understanding of machine learning and deep learning frameworks such as TensorFlow, PyTorch, Keras, Pandas, and NumPy is required. Hands-on experience with Generative AI tools and frameworks such as LangChain, LlamaIndex, LangGraph, CrewAI, and NVIDIA NeMo or NIMs is highly desirable. The candidate should be familiar with deep learning architectures including Transformers, CNNs, and RNNs, along with experience in NLP, large language models, and multimodal AI systems such as GPT, LLaMA, Mistral, Qwen, or Nemotron. Experience with cloud platforms like AWS, Azure, or GCP, along with exposure to Docker, Kubernetes, and Git-based workflows, is also expected.

The position is based in India with flexibility across multiple locations and follows a hybrid working model. This role offers an excellent opportunity to work on advanced AI and Generative AI projects in a collaborative and innovation-driven environment. The organization provides exposure to cutting-edge technologies, opportunities for learning and growth, and the chance to work on impactful real-world solutions.

The ideal candidate should possess strong analytical thinking, problem-solving ability, and a passion for building intelligent systems. Certifications such as NVIDIA Certified Associate in Generative AI will be an added advantage. Strong communication skills and the ability to work effectively in a team-oriented environment are essential for success in this role.

This role is well suited for professionals who are eager to work at the forefront of AI innovation, contribute to enterprise-scale solutions, and grow their career in a dynamic and fast-paced environment.
"""

initial_state = {
    "requirment" : requirment,
    "iteration" : 1,
    "max_iteration" : 5
}

final_state = workflow.invoke(initial_state)

# %%
final_state
# Out:
# {'requirment': '"We are looking for a highly skilled and motivated Data Scientist with strong expertise in Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI to join our growing team. This role requires hands-on experience in building intelligent systems, working with large-scale data, and developing production-ready AI solutions. The ideal candidate should have a strong foundation in data science concepts, modern AI frameworks, and real-world problem-solving abilities, along with the ability to collaborate effectively across teams.\n\nThe candidate is expected to have 3 to 6 years of experience in the Data Science and AI/ML domain, with practical exposure to building, training, and deploying machine learning and deep learning models. Experience in Generative AI, including large language models and multimodal systems, is highly preferred. The role involves working with cutting-edge technologies to design scalable and high-performance AI solutions that solve business problems across domains.\n\nIn this role, you will be responsible for designing, developing, and deploying machine learning and deep learning models for real-world applications. You will work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions. The role also involves developing Generative AI use cases, working with large language models, optimizing models for performance and scalability, and ensuring seamless integration with production systems. You will also contribute to experimentation, model evaluation, and continuous improvement of AI pipelines.\n\nThe ideal candidate should have strong programming skills in Python and be comfortable working in Linux and Windows environments. A solid understanding of machine learning and deep learning frameworks such as TensorFlow, PyTorch, Keras, Pandas, and NumPy is required. Hands-on experience with Generative AI tools and frameworks such as LangChain, LlamaIndex, LangGraph, CrewAI, and NVIDIA NeMo or NIMs is highly desirable. The candidate should be familiar with deep learning architectures including Transformers, CNNs, and RNNs, along with experience in NLP, large language models, and multimodal AI systems such as GPT, LLaMA, Mistral, Qwen, or Nemotron. Experience with cloud platforms like AWS, Azure, or GCP, along with exposure to Docker, Kubernetes, and Git-based workflows, is also expected.\n\nThe position is based in India with flexibility across multiple locations and follows a hybrid working model. This role offers an excellent opportunity to work on advanced AI and Generative AI projects in a collaborative and innovation-driven environment. The organization provides exposure to cutting-edge technologies, opportunities for learning and growth, and the chance to work on impactful real-world solutions.\n\nThe ideal candidate should possess strong analytical thinking, problem-solving ability, and a passion for building intelligent systems. Certifications such as NVIDIA Certified Associate in Generative AI will be an added advantage. Strong communication skills and the ability to work effectively in a team-oriented environment are essential for success in this role.\n\nThis role is well suited for professionals who are eager to work at the forefront of AI innovation, contribute to enterprise-scale solutions, and grow their career in a dynamic and fast-paced environment.\n',
#  'iteration': 5,
#  'max_iteration': 5,
#  'jd': '**Optimized Job Description:**\n\n**Job Title:** Senior Data Scientist - Artificial Intelligence & Generative AI\n\n**A Highlight about Key Requirement of this Job:**\nWe are seeking an exceptional Senior Data Scientist to join our team, who has expertise in Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI to drive innovation and build cutting-edge AI solutions that solve real-world problems.\n\n**Experience:**\n* 3 to 6 years of experience in the Data Science and AI/ML domain\n* Practical exposure to building, training, and deploying machine learning and deep learning models\n* Experience in Generative AI, including large language models and multimodal systems, is highly preferred\n\n**About the Role:**\nAs a Senior Data Scientist, you will be responsible for designing, developing, and deploying machine learning and deep learning models for real-world applications. You will work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions.\n\n**Key Responsibilities:**\n* Design, develop, and deploy machine learning and deep learning models for real-world applications\n* Work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions\n* Develop Generative AI use cases, work with large language models, optimize models for performance and scalability, and ensure seamless integration with production systems\n* Contribute to experimentation, model evaluation, and continuous improvement of AI pipelines\n\n**Requirements:**\n* Strong programming skills in Python\n* Comfortable working in Linux and Windows environments\n* Solid understanding of machine learning and deep learning frameworks such as TensorFlow, PyTorch, Keras, Pandas, and NumPy\n* Hands-on experience with Generative AI tools and frameworks such as LangChain, LlamaIndex, LangGraph, CrewAI, and NVIDIA NeMo or NIMs\n* Familiarity with deep learning architectures including Transformers, CNNs, and RNNs\n* Experience in NLP, large language models, and multimodal AI systems such as GPT, LLaMA, Mistral, Qwen, or Nemotron\n* Experience with cloud platforms like AWS, Azure, or GCP\n* Exposure to Docker, Kubernetes, and Git-based workflows\n* Strong analytical thinking, problem-solving ability, and a passion for building intelligent systems\n* Excellent communication and collaboration skills\n\n**Location:**\nThe position is based in India with flexibility across multiple locations and follows a hybrid working model.\n\n**Why Join Us?**\nThis role offers an excellent opportunity to work on advanced AI and Generative AI projects in a collaborative and innovation-driven environment. At [Company Name], we are committed to driving innovation and building cutting-edge AI solutions that solve real-world problems.\n\n**About Company:**\nAt [Company Name], we are a leading innovator in the field of Artificial Intelligence and Generative AI. Our mission is to harness the power of AI to solve complex problems and improve lives. We are a collaborative and innovation-driven organization that values teamwork, creativity, and continuous learning.\n\n**Key Skills:**\n* Data Science and AI/ML\n* Python programming\n* Machine Learning and Deep Learning frameworks\n* Generative AI tools and frameworks\n* Cloud platforms\n* Docker, Kubernetes, and Git-based workflows\n* NLP and large language models\n* Multimodal AI systems\n\n**Certifications:**\nNVIDIA Certified Associate in Generative AI is an added advantage.\n\n**Benefits:**\n* Competitive salary and benefits package\n* Opportunities for professional growth and development\n* Collaborative and innovation-driven work environment\n* Flexible working hours and remote work options\n* Access to cutting-edge technologies and tools\n* Recognition and rewards for outstanding performance\n\n**How to Apply:**\nIf you are a motivated and talented Senior Data Scientist looking for a new challenge, please  ...
#  'evaluation': 'accept',
#  'feedback': 'The provided JD lacks essential details, making it difficult to assess its professionalism, quality, and format. To provide a thorough evaluation, I need more information about the job description.',
#  'jd_history': ["Here's the job description for the Data Scientist position:\n\n**Job Title:**\nData Scientist - Artificial Intelligence & Generative AI\n\n**A Highlight about Key Requirement of this Job:**\n\nWe are seeking a seasoned Data Scientist to join our team, who has expertise in Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI to drive innovation and build cutting-edge AI solutions.\n\n**Experience:**\n\n* 3 to 6 years of experience in the Data Science and AI/ML domain\n* Practical exposure to building, training, and deploying machine learning and deep learning models\n* Experience in Generative AI, including large language models and multimodal systems, is highly preferred\n\n**About the Role:**\n\nWe are looking for a highly skilled and motivated Data Scientist to join our growing team. This role requires hands-on experience in building intelligent systems, working with large-scale data, and developing production-ready AI solutions. The ideal candidate should have a strong foundation in data science concepts, modern AI frameworks, and real-world problem-solving abilities, along with the ability to collaborate effectively across teams.\n\n**Key Responsibilities:**\n\n* Design, develop, and deploy machine learning and deep learning models for real-world applications\n* Work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions\n* Develop Generative AI use cases, work with large language models, optimize models for performance and scalability, and ensure seamless integration with production systems\n* Contribute to experimentation, model evaluation, and continuous improvement of AI pipelines\n\n**Requirements:**\n\n* Strong programming skills in Python\n* Comfortable working in Linux and Windows environments\n* Solid understanding of machine learning and deep learning frameworks such as TensorFlow, PyTorch, Keras, Pandas, and NumPy\n* Hands-on experience with Generative AI tools and frameworks such as LangChain, LlamaIndex, LangGraph, CrewAI, and NVIDIA NeMo or NIMs\n* Familiarity with deep learning architectures including Transformers, CNNs, and RNNs\n* Experience in NLP, large language models, and multimodal AI systems such as GPT, LLaMA, Mistral, Qwen, or Nemotron\n* Experience with cloud platforms like AWS, Azure, or GCP\n* Exposure to Docker, Kubernetes, and Git-based workflows\n* Strong analytical thinking, problem-solving ability, and a passion for building intelligent systems\n\n**Location:**\n\nThe position is based in India with flexibility across multiple locations and follows a hybrid working model.\n\n**Why Join Us?**\n\nThis role offers an excellent opportunity to work on advanced AI and Generative AI projects in a collaborative and innovation-driven environment. The organization provides exposure to cutting-edge technologies, opportunities for learning and growth, and the chance to work on impactful real-world solutions.\n\n**Key Skills:**\n\n* Data Science and AI/ML\n* Python programming\n* Machine Learning and Deep Learning frameworks\n* Generative AI tools and frameworks\n* Cloud platforms\n* Docker, Kubernetes, and Git-based workflows\n* NLP and large language models\n* Multimodal AI systems\n\n**About Company:**\n\nOur organization is a leading innovator in the field of Artificial Intelligence and Generative AI. We are committed to driving innovation and building cutting-edge AI solutions that solve real-world problems. We offer a collaborative and innovation-driven environment, where you can grow your career in a dynamic and fast-paced environment.",
#   'Based on the provided feedback, I will optimize the job description to include the required sections and maintain clarity and conciseness.\n\n**Job Title:** Data Scientist - Artificial Intelligence & Generative AI\n\n**A Highlight about Key Requirement of this Job:**\nWe are seeking a seasoned Data Scientist to join our team, who has expertise in Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI to drive innovation and build cutting-edge AI solutions.\n\n**Experience:**\n* 3 to 6 years of experience in the Data Science and AI/ML domain\n* Practical exposure to building, training, and deploying machine learning and deep learning models\n* Experience in Generative AI, including large language models and multimodal systems, is highly preferred\n\n**About the Role:**\nWe are looking for a highly skilled and motivated Data Scientist to join our growing team. This role requires hands-on experience in building intelligent systems, working with large-scale data, and developing production-ready AI solutions. The ideal candidate should have a strong foundation in data science concepts, modern AI frameworks, and real-world problem-solving abilities, along with the ability to collaborate effectively across teams.\n\n**Key Responsibilities:**\n* Design, develop, and deploy machine learning and deep learning models for real-world applications\n* Work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions\n* Develop Generative AI use cases, work with large language models, optimize models for performance and scalability, and ensure seamless integration with production systems\n* Contribute to experimentation, model evaluation, and continuous improvement of AI pipelines\n\n**Requirements:**\n* Strong programming skills in Python\n* Comfortable working in Linux and Windows environments\n* Solid understanding of machine learning and deep learning frameworks such as TensorFlow, PyTorch, Keras, Pandas, and NumPy\n* Hands-on experience with Generative AI tools and frameworks such as LangChain, LlamaIndex, LangGraph, CrewAI, and NVIDIA NeMo or NIMs\n* Familiarity with deep learning architectures including Transformers, CNNs, and RNNs\n* Experience in NLP, large language models, and multimodal AI systems such as GPT, LLaMA, Mistral, Qwen, or Nemotron\n* Experience with cloud platforms like AWS, Azure, or GCP\n* Exposure to Docker, Kubernetes, and Git-based workflows\n* Strong analytical thinking, problem-solving ability, and a passion for building intelligent systems\n\n**Location:**\nThe position is based in India with flexibility across multiple locations and follows a hybrid working model.\n\n**Why Join Us?**\nThis role offers an excellent opportunity to work on advanced AI and Generative AI projects in a collaborative and innovation-driven environment. The organization provides exposure to cutting-edge technologies, opportunities for learning and growth, and the chance to work on impactful real-world solutions.\n\n**Key Skills:**\n* Data Science and AI/ML\n* Python programming\n* Machine Learning and Deep Learning frameworks\n* Generative AI tools and frameworks\n* Cloud platforms\n* Docker, Kubernetes, and Git-based workflows\n* NLP and large language models\n* Multimodal AI systems\n\n**About Company:**\nOur organization is a leading innovator in the field of Artificial Intelligence and Generative AI. We are committed to driving innovation and building cutting-edge AI solutions that solve real-world problems. We offer a collaborative and innovation-driven environment, where you can grow your career in a dynamic and fast-paced environment.\n\n**Certifications:** NVIDIA Certified Associate in Generative AI is an added advantage.\n\nNote: I have maintained the same content and structure as the original job description while ensuring that all the required sections are included. I have also added the certification mentioned in the feedback as an added advan ...
#   '**Optimized Job Description:**\n\n**Job Title:** Senior Data Scientist - Artificial Intelligence & Generative AI\n\n**A Highlight about Key Requirement of this Job:**\nWe are seeking an exceptional Senior Data Scientist to join our team, who has expertise in Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI to drive innovation and build cutting-edge AI solutions that solve real-world problems.\n\n**Experience:**\n* 3 to 6 years of experience in the Data Science and AI/ML domain\n* Practical exposure to building, training, and deploying machine learning and deep learning models\n* Experience in Generative AI, including large language models and multimodal systems, is highly preferred\n\n**About the Role:**\nWe are looking for a highly skilled and motivated Senior Data Scientist to join our growing team. This role requires hands-on experience in building intelligent systems, working with large-scale data, and developing production-ready AI solutions. The ideal candidate should have a strong foundation in data science concepts, modern AI frameworks, and real-world problem-solving abilities, along with the ability to collaborate effectively across teams.\n\n**Key Responsibilities:**\n* Design, develop, and deploy machine learning and deep learning models for real-world applications\n* Work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions\n* Develop Generative AI use cases, work with large language models, optimize models for performance and scalability, and ensure seamless integration with production systems\n* Contribute to experimentation, model evaluation, and continuous improvement of AI pipelines\n\n**Requirements:**\n* Strong programming skills in Python\n* Comfortable working in Linux and Windows environments\n* Solid understanding of machine learning and deep learning frameworks such as TensorFlow, PyTorch, Keras, Pandas, and NumPy\n* Hands-on experience with Generative AI tools and frameworks such as LangChain, LlamaIndex, LangGraph, CrewAI, and NVIDIA NeMo or NIMs\n* Familiarity with deep learning architectures including Transformers, CNNs, and RNNs\n* Experience in NLP, large language models, and multimodal AI systems such as GPT, LLaMA, Mistral, Qwen, or Nemotron\n* Experience with cloud platforms like AWS, Azure, or GCP\n* Exposure to Docker, Kubernetes, and Git-based workflows\n* Strong analytical thinking, problem-solving ability, and a passion for building intelligent systems\n* Excellent communication and collaboration skills\n\n**Location:**\nThe position is based in India with flexibility across multiple locations and follows a hybrid working model.\n\n**Why Join Us?**\nThis role offers an excellent opportunity to work on advanced AI and Generative AI projects in a collaborative and innovation-driven environment. Our organization is committed to driving innovation and building cutting-edge AI solutions that solve real-world problems. We offer a dynamic and fast-paced environment, where you can grow your career and contribute to impactful projects.\n\n**About Us:**\nAt [Company Name], we are a leading innovator in the field of Artificial Intelligence and Generative AI. Our mission is to harness the power of AI to solve complex problems and improve lives. We are a collaborative and innovation-driven organization that values teamwork, creativity, and continuous learning.\n\n**Key Skills:**\n* Data Science and AI/ML\n* Python programming\n* Machine Learning and Deep Learning frameworks\n* Generative AI tools and frameworks\n* Cloud platforms\n* Docker, Kubernetes, and Git-based workflows\n* NLP and large language models\n* Multimodal AI systems\n\n**Certifications:** NVIDIA Certified Associate in Generative AI is an added advantage.\n\n**Benefits:**\n* Competitive salary and benefits package\n* Opportunities for professional growth and development\n* Collaborative and innovation-driven work environment\n* Flexible work ...
#   '**Optimized Job Description:**\n\n**Job Title:** Senior Data Scientist - Artificial Intelligence & Generative AI\n\n**A Highlight about Key Requirement of this Job:**\nWe are seeking an exceptional Senior Data Scientist to join our team, who has expertise in Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI to drive innovation and build cutting-edge AI solutions that solve real-world problems.\n\n**Experience:**\n* 3 to 6 years of experience in the Data Science and AI/ML domain\n* Practical exposure to building, training, and deploying machine learning and deep learning models\n* Experience in Generative AI, including large language models and multimodal systems, is highly preferred\n\n**About the Role:**\nAs a Senior Data Scientist, you will be responsible for designing, developing, and deploying machine learning and deep learning models for real-world applications. You will work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions.\n\n**Key Responsibilities:**\n* Design, develop, and deploy machine learning and deep learning models for real-world applications\n* Work closely with cross-functional teams to understand business requirements and translate them into efficient AI solutions\n* Develop Generative AI use cases, work with large language models, optimize models for performance and scalability, and ensure seamless integration with production systems\n* Contribute to experimentation, model evaluation, and continuous improvement of AI pipelines\n\n**Requirements:**\n* Strong programming skills in Python\n* Comfortable working in Linux and Windows environments\n* Solid understanding of machine learning and deep learning frameworks such as TensorFlow, PyTorch, Keras, Pandas, and NumPy\n* Hands-on experience with Generative AI tools and frameworks such as LangChain, LlamaIndex, LangGraph, CrewAI, and NVIDIA NeMo or NIMs\n* Familiarity with deep learning architectures including Transformers, CNNs, and RNNs\n* Experience in NLP, large language models, and multimodal AI systems such as GPT, LLaMA, Mistral, Qwen, or Nemotron\n* Experience with cloud platforms like AWS, Azure, or GCP\n* Exposure to Docker, Kubernetes, and Git-based workflows\n* Strong analytical thinking, problem-solving ability, and a passion for building intelligent systems\n* Excellent communication and collaboration skills\n\n**Location:**\nThe position is based in India with flexibility across multiple locations and follows a hybrid working model.\n\n**Why Join Us?**\nThis role offers an excellent opportunity to work on advanced AI and Generative AI projects in a collaborative and innovation-driven environment. At [Company Name], we are committed to driving innovation and building cutting-edge AI solutions that solve real-world problems.\n\n**About Company:**\nAt [Company Name], we are a leading innovator in the field of Artificial Intelligence and Generative AI. Our mission is to harness the power of AI to solve complex problems and improve lives. We are a collaborative and innovation-driven organization that values teamwork, creativity, and continuous learning.\n\n**Key Skills:**\n* Data Science and AI/ML\n* Python programming\n* Machine Learning and Deep Learning frameworks\n* Generative AI tools and frameworks\n* Cloud platforms\n* Docker, Kubernetes, and Git-based workflows\n* NLP and large language models\n* Multimodal AI systems\n\n**Certifications:**\nNVIDIA Certified Associate in Generative AI is an added advantage.\n\n**Benefits:**\n* Competitive salary and benefits package\n* Opportunities for professional growth and development\n* Collaborative and innovation-driven work environment\n* Flexible working hours and remote work options\n* Access to cutting-edge technologies and tools\n* Recognition and rewards for outstanding performance\n\n**How to Apply:**\nIf you are a motivated and talented Senior Data Scientist looking for a new challenge, please submi ...
#  'feedback_history': ['value=1',
#   "Good effort! Here's my evaluation: **Professionalism:** 7/10 (The JD doesn't provide much company information or culture overview. It mainly focuses on job responsibilities and requirements. Adding some context about the company would enhance professionalism.) **Quality:** 8/10 (The job description covers most aspects of a typical job, including responsibilities, qualifications, and working conditions. However, it could be more detailed in specific areas like skills required and expected outcomes.) **Format:** 9/10 (The JD is concise, easy to read, and uses clear headings and bullet points. The formatting could be improved by adding whitespace and making the text more readable.) Overall, this is a good but not exceptional job description.",
#   'Below is my evaluation of the job description based on professionalism, quality, and format.',
#   'The provided JD lacks essential details, making it difficult to assess its professionalism, quality, and format. To provide a thorough evaluation, I need more information about the job description.']}
