# %%
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from typing import TypedDict, Annotated
from langchain.messages import SystemMessage, HumanMessage
from langchain_groq import ChatGroq
from langgraph.checkpoint.memory import InMemorySaver
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
class ChatState(TypedDict):
    message : Annotated[list[str], add_messages]

# %%
def chat_node(state : ChatState):
    query = state["message"]
    response = model.invoke(query)
    return {"message" : response}

# %%
graph = StateGraph(ChatState)

graph.add_node("chat_node", chat_node)

graph.add_edge(START, "chat_node")
graph.add_edge("chat_node", END)

check_pointer = InMemorySaver()

workflow = graph.compile(checkpointer=check_pointer)

# %%
config = {"configurable" : {"thread_id" : "1"}}

workflow.get_state(config=config)
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
query = "what is ML"
initial_state = {"message" : HumanMessage(query)}

workflow.invoke(initial_state,config=config)
# Out:
# {'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'),
#   AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b88bf-8b6 ...

# %%
query = "what is AI"
initial_state = {"message" : HumanMessage(query)}


workflow.invoke(initial_state,config=config)
# Out:
# {'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'),
#   AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b88bf-8b6 ...
#   HumanMessage(content='what is AI', additional_kwargs={}, response_metadata={}, id='f802f3bc-d5b2-4f97-8959-ee833a3a970e'),
#   AIMessage(content='AI stands for Artificial Intelligence, which refers to the development of computer systems that can perform tasks that typically require human intelligence. AI involves the creation of algorithms and statistical models that enable machines to learn, reason, and interact with their environment in a way that simulates human cognition.\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: This type of AI is designed to perform a specific task, such as playing chess, recognizing faces, or translating languages. It is trained on a specific dataset and is not capable of general reasoning or problem-solving.\n2. **General or Strong AI**: This type of AI is designed to perform any intellectual task that a human can, such as reasoning, problem-solving, and learning. It is still in the early stages of development and is not yet fully realized.\n3. **Superintelligence**: This type of AI is far more intelligent than the best human minds and is capable of solving problems that are beyond human capabilities.\n\nAI systems can be categorized into several levels of complexity, including:\n\n1. **Rule-based systems**: These systems use a set of pre-defined rules to make decisions.\n2. **Decision trees**: These systems use a decision tree to make decisions based on a set of inputs.\n3. **Neural networks**: These systems use a network of interconnected nodes (neurons) to make decisions based on patterns in the data.\n4. **Evolutionary algorithms**: These systems use principles of evolution and natural selection to make decisions.\n\nAI has many applications, including:\n\n1. **Virtual assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant, can perform tasks such as setting reminders, making calls, and sending messages.\n2. **Image and speech recognition**: AI-powered image and speech recognition systems can recognize objects, people, and spoken words.\n3. **Predictive maintenance**: AI-powered predictive maintenance systems can predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Autonomous vehicles**: AI-powered autonomous vehicles can navigate through roads and traffic without human intervention.\n5. **Healthcare**: AI-powered healthcare systems can analyze medical data, diagnose diseases, and develop personalized treatment plans.\n\nSome popular AI techniques include:\n\n1. **Machine learning**: AI systems can learn from data and improve their performance over time.\n2. **Deep learning**: AI systems can use neural networks to analyze and recognize patterns in data.\n3. **Natural language processing**: AI systems can analyze and understand human language.\n4. **Computer vision**: AI systems can analyze and understand visual data from images and videos.\n5. **Robotics**: AI systems can control robots to perform tasks in a physical environment.\n\nSome popular AI frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training AI models.\n2. **PyTorch**: An open-source framework for building and training AI models.\n3. **Keras**: A high-level framework for building and training AI models.\n4. **OpenCV**: A computer vision library for building AI-powered image and video analysis systems.\n5. **NLTK**: A natural language processing library for building AI-powered text analysis systems.\n\nIn summary, AI refers to the development of computer systems that can perform tasks that typically require human intelligence. AI has many applications and is a rapidly evolving field that is changing the way we live and work.\n\n**Types of AI:**\n\n1. **Artificial General Intelligence (AGI)**: AI that can perform any intellectual task that a human can.\n2. **Artificial Superintelligence (ASI)**: AI that is far more intelligent than the best human minds.\n3. **Narrow or Weak AI**: AI that is designed to perform a specific task.\n4. **Superintelligence**: AI that is far more intelligent than the best human minds.\n\n**AI ...

# %%
# return the message histories after end of the workflows
workflow.get_state(config=config)
# Out:
# StateSnapshot(values={'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'), AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'system ...

# %%
# return the message histories of the workflows at the end of each edge
list(workflow.get_state_history(config=config))
# Out:
# [StateSnapshot(values={'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'), AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'syste ...
#  StateSnapshot(values={'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'), AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'syste ...
#  StateSnapshot(values={'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'), AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'syste ...
#  StateSnapshot(values={'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'), AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'syste ...
#  StateSnapshot(values={'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb')]}, next=('chat_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e95fc-db5f-60ec-8000-a2cfbbdeedf4'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-04T11:23:33.090317+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e95fc-db5d-60d7-bfff-64395763683f'}}, tasks=(PregelTask(id='d8310b9a-cbf1-679c-9b2c-7d2861057a06', name='chat_node', path=('__pregel_pull', 'chat_node'), error=None, interrupts=(), state=None, result={'message': AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is ...
#  StateSnapshot(values={'message': []}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e95fc-db5d-60d7-bfff-64395763683f'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-04T11:23:33.089499+00:00', parent_config=None, tasks=(PregelTask(id='44ee6e0a-842c-aa27-e346-4faaed9590a5', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'message': HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb')}),), interrupts=())]

# %%
values = workflow.get_state(config=config).values["message"]
for msg in values:
    print(msg)
    print("-----------------------------------------")
# Out:
# content='what is ML' additional_kwargs={} response_metadata={} id='a448509f-67ff-4082-8f52-6771b7951afb'
# -----------------------------------------
# content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019b88bf-8b63-76c3-b4f1-6df ...
# -----------------------------------------
# content='what is AI' additional_kwargs={} response_metadata={} id='f802f3bc-d5b2-4f97-8959-ee833a3a970e'
# -----------------------------------------
# content='AI stands for Artificial Intelligence, which refers to the development of computer systems that can perform tasks that typically require human intelligence. AI involves the creation of algorithms and statistical models that enable machines to learn, reason, and interact with their environment in a way that simulates human cognition.\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: This type of AI is designed to perform a specific task, such as playing chess, recognizing faces, or translating languages. It is trained on a specific dataset and is not capable of general reasoning or problem-solving.\n2. **General or Strong AI**: This type of AI is designed to perform any intellectual task that a human can, such as reasoning, problem-solving, and learning. It is still in the early stages of development and is not yet fully realized.\n3. **Superintelligence**: This type of AI is far more intelligent than the best human minds and is capable of solving problems that are beyond human capabilities.\n\nAI systems can be categorized into several levels of complexity, including:\n\n1. **Rule-based systems**: These systems use a set of pre-defined rules to make decisions.\n2. **Decision trees**: These systems use a decision tree to make decisions based on a set of inputs.\n3. **Neural networks**: These systems use a network of interconnected nodes (neurons) to make decisions based on patterns in the data.\n4. **Evolutionary algorithms**: These systems use principles of evolution and natural selection to make decisions.\n\nAI has many applications, including:\n\n1. **Virtual assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant, can perform tasks such as setting reminders, making calls, and sending messages.\n2. **Image and speech recognition**: AI-powered image and speech recognition systems can recognize objects, people, and spoken words.\n3. **Predictive maintenance**: AI-powered predictive maintenance systems can predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Autonomous vehicles**: AI-powered autonomous vehicles can navigate through roads and traffic without human intervention.\n5. **Healthcare**: AI-powered healthcare systems can analyze medical data, diagnose diseases, and develop personalized treatment plans.\n\nSome popular AI techniques include:\n\n1. **Machine learning**: AI systems can learn from data and improve their performance over time.\n2. **Deep learning**: AI systems can use neural networks to analyze and recognize patterns in data.\n3. **Natural language processing**: AI systems can analyze and understand human language.\n4. **Computer vision**: AI systems can analyze and understand visual data from images and videos.\n5. **Robotics**: AI systems can control robots to perform tasks in a physical environment.\n\nSome popular AI frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training AI models.\n2. **PyTorch**: An open-source framework for building and training AI models.\n3. **Keras**: A high-level framework for building and training AI models.\n4. **OpenCV**: A computer vision library for building AI-powered image and video analysis systems.\n5. **NLTK**: A natural language processing library for building AI-powered text analysis systems.\n\nIn summary, AI refers to the development of computer systems that can perform tasks that typically require human intelligence. AI has many applications and is a rapidly evolving field that is changing the way we live and work.\n\n**Types of AI:**\n\n1. **Artificial General Intelligence (AGI)**: AI that can perform any intellectual task that a human can.\n2. **Artificial Superintelligence (ASI)**: AI that is far more intelligent than the best human minds.\n3. **Narrow or Weak AI**: AI that is designed to perform a specific task.\n4. **Superintelligence**: AI that is far more intelligent than the best human minds.\n\n**AI Application ...
# -----------------------------------------

# %%
values
# Out:
# [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'),
#  AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b88bf-8b63 ...
#  HumanMessage(content='what is AI', additional_kwargs={}, response_metadata={}, id='f802f3bc-d5b2-4f97-8959-ee833a3a970e'),
#  AIMessage(content='AI stands for Artificial Intelligence, which refers to the development of computer systems that can perform tasks that typically require human intelligence. AI involves the creation of algorithms and statistical models that enable machines to learn, reason, and interact with their environment in a way that simulates human cognition.\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: This type of AI is designed to perform a specific task, such as playing chess, recognizing faces, or translating languages. It is trained on a specific dataset and is not capable of general reasoning or problem-solving.\n2. **General or Strong AI**: This type of AI is designed to perform any intellectual task that a human can, such as reasoning, problem-solving, and learning. It is still in the early stages of development and is not yet fully realized.\n3. **Superintelligence**: This type of AI is far more intelligent than the best human minds and is capable of solving problems that are beyond human capabilities.\n\nAI systems can be categorized into several levels of complexity, including:\n\n1. **Rule-based systems**: These systems use a set of pre-defined rules to make decisions.\n2. **Decision trees**: These systems use a decision tree to make decisions based on a set of inputs.\n3. **Neural networks**: These systems use a network of interconnected nodes (neurons) to make decisions based on patterns in the data.\n4. **Evolutionary algorithms**: These systems use principles of evolution and natural selection to make decisions.\n\nAI has many applications, including:\n\n1. **Virtual assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant, can perform tasks such as setting reminders, making calls, and sending messages.\n2. **Image and speech recognition**: AI-powered image and speech recognition systems can recognize objects, people, and spoken words.\n3. **Predictive maintenance**: AI-powered predictive maintenance systems can predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Autonomous vehicles**: AI-powered autonomous vehicles can navigate through roads and traffic without human intervention.\n5. **Healthcare**: AI-powered healthcare systems can analyze medical data, diagnose diseases, and develop personalized treatment plans.\n\nSome popular AI techniques include:\n\n1. **Machine learning**: AI systems can learn from data and improve their performance over time.\n2. **Deep learning**: AI systems can use neural networks to analyze and recognize patterns in data.\n3. **Natural language processing**: AI systems can analyze and understand human language.\n4. **Computer vision**: AI systems can analyze and understand visual data from images and videos.\n5. **Robotics**: AI systems can control robots to perform tasks in a physical environment.\n\nSome popular AI frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training AI models.\n2. **PyTorch**: An open-source framework for building and training AI models.\n3. **Keras**: A high-level framework for building and training AI models.\n4. **OpenCV**: A computer vision library for building AI-powered image and video analysis systems.\n5. **NLTK**: A natural language processing library for building AI-powered text analysis systems.\n\nIn summary, AI refers to the development of computer systems that can perform tasks that typically require human intelligence. AI has many applications and is a rapidly evolving field that is changing the way we live and work.\n\n**Types of AI:**\n\n1. **Artificial General Intelligence (AGI)**: AI that can perform any intellectual task that a human can.\n2. **Artificial Superintelligence (ASI)**: AI that is far more intelligent than the best human minds.\n3. **Narrow or Weak AI**: AI that is designed to perform a specific task.\n4. **Superintelligence**: AI that is far more intelligent than the best human minds.\n\n**AI  ...

# %%
workflow.get_state(config=config).values
# Out:
# {'message': [HumanMessage(content='what is ML', additional_kwargs={}, response_metadata={}, id='a448509f-67ff-4082-8f52-6771b7951afb'),
#   AIMessage(content="ML stands for Machine Learning. It is a subset of Artificial Intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.\n\nMachine Learning is a field of study that focuses on the development of algorithms and techniques that enable machines to learn from experience, without being explicitly programmed. This allows machines to automatically improve their performance on a task, such as image recognition, natural language processing, or decision-making, by learning from data and adapting to new situations.\n\nThere are several key aspects of Machine Learning:\n\n1. **Data**: Machine Learning algorithms require large amounts of data to learn from. This data can come in various forms, such as images, text, audio, or sensor readings.\n2. **Algorithms**: Machine Learning algorithms are used to analyze and process the data. These algorithms can be categorized into three types: supervised, unsupervised, and reinforcement learning.\n3. **Model**: A Machine Learning model is a mathematical representation of the data and the relationships between the variables. The model is trained on the data to learn patterns and make predictions.\n4. **Training**: The process of training a Machine Learning model involves feeding it with data and adjusting the model's parameters to optimize its performance.\n5. **Testing**: Once the model is trained, it is tested on new, unseen data to evaluate its performance and accuracy.\n\nMachine Learning has many applications, including:\n\n1. **Image recognition**: Machines can be trained to recognize objects, faces, and scenes from images.\n2. **Natural language processing**: Machines can be trained to understand and generate human language, including text and speech.\n3. **Predictive maintenance**: Machines can be trained to predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Recommendation systems**: Machines can be trained to recommend products or services based on user behavior and preferences.\n5. ** Autonomous vehicles**: Machines can be trained to control vehicles and navigate through roads and traffic.\n\nSome popular Machine Learning techniques include:\n\n1. **Deep learning**: A type of Machine Learning that uses neural networks to analyze data.\n2. **Support vector machines**: A type of Machine Learning algorithm that uses a kernel trick to transform data into a higher-dimensional space.\n3. **Decision trees**: A type of Machine Learning algorithm that uses a tree-like model to make decisions.\n4. **Clustering**: A type of Machine Learning algorithm that groups similar data points together.\n5. **Regression**: A type of Machine Learning algorithm that predicts continuous values.\n\nSome popular Machine Learning frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training Machine Learning models.\n2. **PyTorch**: An open-source framework for building and training Machine Learning models.\n3. **Scikit-learn**: A popular library for building and training Machine Learning models.\n4. **Keras**: A high-level framework for building and training Machine Learning models.\n\nIn summary, Machine Learning is a powerful tool for enabling machines to learn from data and make decisions. Its applications are vast and varied, and it has the potential to revolutionize many industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 38, 'total_tokens': 677, 'completion_time': 1.150878517, 'completion_tokens_details': None, 'prompt_time': 0.003097167, 'prompt_tokens_details': None, 'queue_time': 0.057133103, 'total_time': 1.153975684}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b88bf-8b6 ...
#   HumanMessage(content='what is AI', additional_kwargs={}, response_metadata={}, id='f802f3bc-d5b2-4f97-8959-ee833a3a970e'),
#   AIMessage(content='AI stands for Artificial Intelligence, which refers to the development of computer systems that can perform tasks that typically require human intelligence. AI involves the creation of algorithms and statistical models that enable machines to learn, reason, and interact with their environment in a way that simulates human cognition.\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: This type of AI is designed to perform a specific task, such as playing chess, recognizing faces, or translating languages. It is trained on a specific dataset and is not capable of general reasoning or problem-solving.\n2. **General or Strong AI**: This type of AI is designed to perform any intellectual task that a human can, such as reasoning, problem-solving, and learning. It is still in the early stages of development and is not yet fully realized.\n3. **Superintelligence**: This type of AI is far more intelligent than the best human minds and is capable of solving problems that are beyond human capabilities.\n\nAI systems can be categorized into several levels of complexity, including:\n\n1. **Rule-based systems**: These systems use a set of pre-defined rules to make decisions.\n2. **Decision trees**: These systems use a decision tree to make decisions based on a set of inputs.\n3. **Neural networks**: These systems use a network of interconnected nodes (neurons) to make decisions based on patterns in the data.\n4. **Evolutionary algorithms**: These systems use principles of evolution and natural selection to make decisions.\n\nAI has many applications, including:\n\n1. **Virtual assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant, can perform tasks such as setting reminders, making calls, and sending messages.\n2. **Image and speech recognition**: AI-powered image and speech recognition systems can recognize objects, people, and spoken words.\n3. **Predictive maintenance**: AI-powered predictive maintenance systems can predict when equipment is likely to fail, allowing for proactive maintenance.\n4. **Autonomous vehicles**: AI-powered autonomous vehicles can navigate through roads and traffic without human intervention.\n5. **Healthcare**: AI-powered healthcare systems can analyze medical data, diagnose diseases, and develop personalized treatment plans.\n\nSome popular AI techniques include:\n\n1. **Machine learning**: AI systems can learn from data and improve their performance over time.\n2. **Deep learning**: AI systems can use neural networks to analyze and recognize patterns in data.\n3. **Natural language processing**: AI systems can analyze and understand human language.\n4. **Computer vision**: AI systems can analyze and understand visual data from images and videos.\n5. **Robotics**: AI systems can control robots to perform tasks in a physical environment.\n\nSome popular AI frameworks and libraries include:\n\n1. **TensorFlow**: An open-source framework for building and training AI models.\n2. **PyTorch**: An open-source framework for building and training AI models.\n3. **Keras**: A high-level framework for building and training AI models.\n4. **OpenCV**: A computer vision library for building AI-powered image and video analysis systems.\n5. **NLTK**: A natural language processing library for building AI-powered text analysis systems.\n\nIn summary, AI refers to the development of computer systems that can perform tasks that typically require human intelligence. AI has many applications and is a rapidly evolving field that is changing the way we live and work.\n\n**Types of AI:**\n\n1. **Artificial General Intelligence (AGI)**: AI that can perform any intellectual task that a human can.\n2. **Artificial Superintelligence (ASI)**: AI that is far more intelligent than the best human minds.\n3. **Narrow or Weak AI**: AI that is designed to perform a specific task.\n4. **Superintelligence**: AI that is far more intelligent than the best human minds.\n\n**AI ...
